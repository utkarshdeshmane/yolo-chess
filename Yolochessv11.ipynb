# %%
# !pip install Ultralytics
# Out:
# ...
#    ---------------------------------------- 0.0/922.2 kB ? eta -:--:--
#    ---------------------------------- ----- 786.4/922.2 kB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 922.2/922.2 kB 2.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#     --------------------------------------- 0.8/39.5 MB 3.7 MB/s eta 0:00:11
#    - -------------------------------------- 1.6/39.5 MB 3.7 MB/s eta 0:00:11
#    -- ------------------------------------- 2.6/39.5 MB 4.3 MB/s eta 0:00:09
#    --- ------------------------------------ 3.7/39.5 MB 4.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.5/39.5 MB 4.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.2/39.5 MB 4.3 MB/s eta 0:00:08
#    ------ --------------------------------- 6.6/39.5 MB 4.4 MB/s eta 0:00:08
#    ------ --------------------------------- 6.8/39.5 MB 4.1 MB/s eta 0:00:09
# ...

# %%
from ultralytics import YOLO

# %%
model=YOLO('best.pt')

# %%
results = model('Chessyolov11.mp4', save=True, project='output', name='chess_detection')
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1473) f:\yolo\Chessyolov11.mp4: 640x384 1 black-bishop, 1 black-king, 1 black-pawn, 193.0ms
# video 1/1 (frame 2/1473) f:\yolo\Chessyolov11.mp4: 640x384 1 black-bishop, 1 black-king, 1 black-pawn, 187.9ms
# video 1/1 (frame 3/1473) f:\yolo\Chessyolov11.mp4: 640x384 1 black-bishop, 1 black-pawn, 180.9ms
# video 1/1 (frame 4/1473) f:\yolo\Chessyolov11.mp4: 640x384 1 black-bishop, 1 black-pawn, 177.0ms
# ...

# %%
# !pip install fastapi uvicorn torch torchvision ultralytics pillow opencv-python
